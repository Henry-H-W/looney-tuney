# %% [markdown]
# ## GENERATING A SONG

# %%
import os
import music21
from music21 import converter, note, chord
import pickle
import numpy as np
from keras.models import load_model
# Out:
# c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py:37: UserWarning: A NumPy version >=1.22.4 and <1.29.0 is required for this version of SciPy (detected version 2.0.2)
#   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 639, in run_forever
#     self._run_once()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1985, in _run_once
#     handle._run()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Richard Augustine\AppData\Local\Temp\ipykernel_41620\3207395046.py", line 6, in <module>
#     from keras.models import load_model
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\__init__.py", line 2, in <module>
#     from keras.api import DTypePolicy
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\__init__.py", line 3, in <module>
#     from keras.src.activations.activations import celu
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\activations.py", line 1, in <module>
#     from keras.src import backend
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\__init__.py", line 10, in <module>
#     from keras.src.backend.common.dtypes import result_type
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\__init__.py", line 2, in <module>
#     from keras.src.backend.common.dtypes import result_type
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\dtypes.py", line 5, in <module>
#     from keras.src.backend.common.variables import standardize_dtype
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\variables.py", line 11, in <module>
#     from keras.src.utils.module_utils import tensorflow as tf
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\__init__.py", line 1, in <module>
#     from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\audio_dataset_utils.py", line 4, in <module>
#     from keras.src.utils import dataset_utils
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\dataset_utils.py", line 9, in <module>
#     from keras.src import tree
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\__init__.py", line 1, in <module>
#     from keras.src.tree.tree_api import assert_same_paths
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\tree_api.py", line 6, in <module>
#     from keras.src.tree import optree_impl as tree_impl
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\optree_impl.py", line 17, in <module>
#     from tensorflow.python.trackable.data_structures import ListWrapper
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py", line 13, in <module>
#     from tensorflow._api.v2.__internal__ import feature_column
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py", line 8, in <module>
#     from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py", line 38, in <module>
#     from tensorflow.python.feature_column import feature_column as fc_old
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 41, in <module>
#     from tensorflow.python.layers import base
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\models.py", line 25, in <module>
#     from tensorflow.python.keras.engine import training_v1
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\engine\training_v1.py", line 46, in <module>
#     from tensorflow.python.keras.engine import training_arrays_v1
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py", line 37, in <module>
#     from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 639, in run_forever
#     self._run_once()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1985, in _run_once
#     handle._run()
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Richard Augustine\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Richard Augustine\AppData\Local\Temp\ipykernel_41620\3207395046.py", line 6, in <module>
#     from keras.models import load_model
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\__init__.py", line 2, in <module>
#     from keras.api import DTypePolicy
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\__init__.py", line 3, in <module>
#     from keras.src.activations.activations import celu
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\activations\activations.py", line 1, in <module>
#     from keras.src import backend
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\__init__.py", line 10, in <module>
#     from keras.src.backend.common.dtypes import result_type
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\__init__.py", line 2, in <module>
#     from keras.src.backend.common.dtypes import result_type
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\dtypes.py", line 5, in <module>
#     from keras.src.backend.common.variables import standardize_dtype
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\variables.py", line 11, in <module>
#     from keras.src.utils.module_utils import tensorflow as tf
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\__init__.py", line 1, in <module>
#     from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\audio_dataset_utils.py", line 4, in <module>
#     from keras.src.utils import dataset_utils
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\dataset_utils.py", line 9, in <module>
#     from keras.src import tree
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\__init__.py", line 1, in <module>
#     from keras.src.tree.tree_api import assert_same_paths
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\tree_api.py", line 6, in <module>
#     from keras.src.tree import optree_impl as tree_impl
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\tree\optree_impl.py", line 17, in <module>
#     from tensorflow.python.trackable.data_structures import ListWrapper
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py", line 13, in <module>
#     from tensorflow._api.v2.__internal__ import feature_column
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py", line 8, in <module>
#     from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py", line 38, in <module>
#     from tensorflow.python.feature_column import feature_column as fc_old
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\feature_column\feature_column.py", line 41, in <module>
#     from tensorflow.python.layers import base
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\layers\base.py", line 16, in <module>
#     from tensorflow.python.keras.legacy_tf_layers import base
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\__init__.py", line 25, in <module>
#     from tensorflow.python.keras import models
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\models.py", line 25, in <module>
#     from tensorflow.python.keras.engine import training_v1
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\keras\engine\training_v1.py", line 71, in <module>
#     from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Richard Augustine\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
model = load_model('model/best_model2.keras')

# %%
# Define constants
SEQUENCE_LENGTH = 100  # Adjust as needed
EPOCHS = 100  # Adjust as needed
BATCH_SIZE = 128  # Adjust as needed
OUTPUT_FILE = 'output.mid'

# Load Chopin MIDI files
data_folder = 'data'
files = [os.path.join(data_folder, file) for file 
         in os.listdir(data_folder) if file.endswith('.midi') or file.endswith('.mid')]

def get_notes():
    """ Get all the notes and chords from the MIDI files in the specified directory """
    notes = []

    for file in files:
        midi = converter.parse(file)
        print("Parsing %s" % file)
        notes_to_parse = midi.flatten()
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.pitches))
    return notes

notes_file_path = 'data/notes'
notes = []

if os.path.exists(notes_file_path):
    # Loading notes from the file
    with open('data/notes', 'rb') as filepath:
        notes = pickle.load(filepath)
else:
    # createing a list of ntoes
    notes = get_notes()
    # saving notes to the file:
    with open('data/notes', 'wb') as filepath:
        pickle.dump(notes, filepath)

# Create input sequences and corresponding output
unique_notes = sorted(set(notes))
note_to_int = dict((note, number) for number, note in enumerate(unique_notes))
int_to_note = dict((number, note) for number, note in enumerate(unique_notes))

input_sequences = []
output_sequences = []
for i in range(len(notes) - SEQUENCE_LENGTH):
    sequence_in = notes[i:i + SEQUENCE_LENGTH]
    sequence_out = notes[i + SEQUENCE_LENGTH]
    input_sequences.append([note_to_int[char] for char in sequence_in])
    output_sequences.append(note_to_int[sequence_out])
# Out:
# Parsing data\MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_03_Track03_wav--1.midi
# Parsing data\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_10_Track10_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_13_Track13_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--2.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--2.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_11_Track11_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav.midi
# Parsing data\MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_17_Track17_wav.midi
# Parsing data\MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R1_2004_06_ORIG_MID--AUDIO_04_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_06_R1_2004_01_ORIG_MID--AUDIO_06_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_06_R1_2004_02-03_ORIG_MID--AUDIO_06_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--1.midi
# Parsing data\MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--2.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.midi
# Parsing data\MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_08_Track08_wav.midi
# Parsing data\MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_10_R1_2004_03-04_ORIG_MID--AUDIO_10_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_10_R1_2004_05_ORIG_MID--AUDIO_10_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R1_2004_04_ORIG_MID--AUDIO_15_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_05_Track05_wav.midi
# Parsing data\MIDI-Unprocessed_XP_18_R1_2004_04_ORIG_MID--AUDIO_18_R1_2004_07_Track07_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_21_R1_2004_03_ORIG_MID--AUDIO_21_R1_2004_04_Track04_wav.midi
# Parsing data\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.midi
# Parsing data\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.midi
# Parsing data\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.midi
# Parsing data\MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.midi

# %%
start = np.random.randint(0, len(input_sequences) - 1)

# %%
pattern = input_sequences[start]
prediction_output = []
number_of_notes_to_generate = 100
for i in range(number_of_notes_to_generate):
    input_sequence = np.reshape(pattern, (1, len(pattern), 1))
    input_sequence = input_sequence / float(len(unique_notes))

    prediction = model.predict(input_sequence, verbose=0)
    index = np.argmax(prediction)
    result = int_to_note[index]
    print(f"{i}/{number_of_notes_to_generate} | {result}")
    prediction_output.append(result)
    pattern.append(index)
    pattern = pattern[1:]
# Out:
# 0/100 | A4.B3.D4.F#4
# 1/100 | A3.E-5.F4.G4
# 2/100 | B-3.G#4.F3.C#4.F4
# 3/100 | A4.C#6.A5
# 4/100 | B-1.B-3.B-4
# 5/100 | B-1.B-3.B-4
# 6/100 | B-3.G#4.F3.C#4.F4
# 7/100 | B-3.G#4.F3.C#4.F4
# 8/100 | A4.F5.E-4.F2.C3.F3
# 9/100 | B-4.E-2.F#4
# 10/100 | B-4.E4.C#4
# 11/100 | B-1.B-3.B-4
# 12/100 | B-1.B-3.B-4
# 13/100 | B-1.B-3.B-4
# 14/100 | A4.G3.A3.C4.F#4.D4
# 15/100 | A3.F#3.B2.A2.F#2
# 16/100 | A3.F#3.B2.A2.F#2
# 17/100 | A3.F#3.B2.A2.F#2
# 18/100 | A3.F#3.B2.A2.F#2
# 19/100 | A3.F#3.B2.A2.F#2
# 20/100 | A3.F#3.B2.A2.F#2
# 21/100 | A3.F#3.B2.A2.F#2
# 22/100 | B-5.B-4.D5.B-2.B-1
# 23/100 | A3.F#3.B2.A2.F#2
# 24/100 | B-5.B-4.D5.B-2.B-1
# 25/100 | A3.F#3.B2.A2.F#2
# 26/100 | B-5.B-4.D5.B-2.B-1
# 27/100 | B-5.F4.C5.C4
# 28/100 | B-5.F4.C5.C4
# 29/100 | B-5.B-4.D5.B-2.B-1
# 30/100 | B-5.B-4.D5.B-2.B-1
# 31/100 | B-5.B-4.D5.B-2.B-1
# 32/100 | B-5.B-4.D5.B-2.B-1
# 33/100 | B-5.B-4.D5.B-2.B-1
# 34/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 35/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 36/100 | B-5.B-4.D5.B-2.B-1
# 37/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 38/100 | B-5.F4.C5.C4
# 39/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 40/100 | B-5.B-4.D5.B-2.B-1
# 41/100 | B-1.B-3.B-4
# 42/100 | B-1.B-3.B-4
# 43/100 | B-1.B-3.B-4
# 44/100 | B-1.B-3.B-4
# 45/100 | B-1.B-3.B-4
# 46/100 | B-1.B-3.B-4
# 47/100 | B-1.B-3.B-4
# 48/100 | B-1.B-3.B-4
# 49/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 50/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 51/100 | A6.F6.C#7.C#4.C#5.E7.A4
# 52/100 | B-4.G#5.C#5.F2.F3
# 53/100 | B-4.G#5.C#5.F2.F3
# 54/100 | A5.A4.F#4
# 55/100 | A5.A4.F#4
# 56/100 | A5.A4.F#4
# 57/100 | A5.A4.F#4
# 58/100 | A5.A4.F#4
# 59/100 | B-5.F#3.B-4.F#5.C#4
# 60/100 | B-5.F#3.B-4.F#5.C#4
# 61/100 | B-5.F#3.B-4.F#5.C#4
# 62/100 | B-4.G#5.C#5.F2.F3
# 63/100 | B-4.G#5.C#5.F2.F3
# 64/100 | A3.E3.C4.A4
# 65/100 | A5.A4.F#4
# 66/100 | B-2.E-2.G3.F4.D4
# 67/100 | B-5.F#3.B-4.F#5.C#4
# 68/100 | B-5.F#3.B-4.F#5.C#4
# 69/100 | B-5.F#3.B-4.F#5.C#4
# 70/100 | B-5.F#3.B-4.F#5.C#4
# 71/100 | B-5.F#3.B-4.F#5.C#4
# 72/100 | A3.F#3.B2.A2.F#2
# 73/100 | A3.E3.C4.A4
# 74/100 | A3.F5.E-4.C5.E-5.F4
# 75/100 | A3.F#3.B2.A2.F#2
# 76/100 | A5.A4.F#4
# 77/100 | B-5.F#3.B-4.F#5.C#4
# 78/100 | B-4.E-4.C4.B-5
# 79/100 | B-5.F#3.B-4.F#5.C#4
# 80/100 | B-4.G#5.C#5.F2.F3
# 81/100 | B-4.G#5.C#5.F2.F3
# 82/100 | B-2.E4.G#3
# 83/100 | B-1.B-3.B-4
# 84/100 | B-2.E4.G#3
# 85/100 | B-2.E4.G#3
# 86/100 | B-5.F#3.B-4.F#5.C#4
# 87/100 | B-5.F#3.B-4.F#5.C#4
# 88/100 | B-4.E-4.C4.B-5
# 89/100 | B-5.F4.C5.C4
# 90/100 | B-5.F#3.B-4.F#5.C#4
# 91/100 | B-3.B-4.B-5.G4.G#3
# 92/100 | B-3.B-4.B-5.G4.G#3
# 93/100 | B-3.B-4.B-5.G4.G#3
# 94/100 | B-1.B-3.B-4
# 95/100 | B-1.B-3.B-4
# 96/100 | A1.C5.A2
# 97/100 | B-5.F#3.B-4.F#5.C#4
# 98/100 | B-2.E4.G#3
# 99/100 | B-5.F4.C5.C4

# %%
# Convert output to MIDI file
output_midi = music21.stream.Stream()
shift = 0
for pattern in prediction_output:
    if '.' in pattern:   # it's a chord
        notes_in_chord = pattern.split('.') # notes for the chord (numbers)
        chord_notes = [music21.note.Note() for _ in notes_in_chord] # real notes
        for i, note_in_chord in enumerate(notes_in_chord):
            chord_notes[i].pitch = music21.pitch.Pitch(note_in_chord)
        chord = music21.chord.Chord(chord_notes, quarterlength=0.5) # the chord per se
        output_midi.insert(shift, chord) # adding the chord to the stream
        shift += 0.3
    else:   # it's a note
        note = music21.note.Note(quarterlength=0.5)
        note.pitch = music21.pitch.Pitch(pattern)
        output_midi.insert(shift, note) # adding the note to the stream
        shift += 0.3

output_midi.write('midi', fp=OUTPUT_FILE)
# Out:
# 'output.mid'
